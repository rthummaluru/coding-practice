# %%
import openai
from dotenv import load_dotenv
import os

# %%
from openai import OpenAI

# %%
load_dotenv()
# Out:
# True

# %%
client = OpenAI()

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[{'role': 'user', 'content': 'is it too late to join the course?'}]
)

# %%
response.choices[0].message.content
# Out:
# "I'm sorry, but I would need more context to answer that question. Could you provide more details about the course you are referring to, such as its start date, enrollment deadline, or any other relevant information?"
